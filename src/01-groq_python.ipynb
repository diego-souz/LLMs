# %%
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv())
# Out:
# True

# %%
from groq import Groq
client = Groq()

# %%
mensagens = [
    {
        "role": "user",
        "content": "Explique a diferença entre llm e langchain. Responda em português" 
    }
]

response = client.chat.completions.create(
    messages=mensagens,
    model="llama3-8b-8192"
)

response
# Out:
# ChatCompletion(id='chatcmpl-12963038-98d0-434d-ae8f-5e03edc51198', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='LLaMA (Large Language Model Application) e LangChain são dois projetos de linguagem natural (Linguagem Natural - LNH) desenvolvidos pela Meta AI, uma empresa líder em tecnologia de linguagem natural e inteligência artificial. Embora ambos sejam modelos de linguagem, existem algumas diferenças importantes entre eles.\n\n**LLaMA**\n\nLLaMA é um modelo de linguagem baseado em transformadores, similar ao BERT e ao RoBERTa. Ele é treinado em uma vasta quantidade de dados de linguagem natural e é capaz de realizar uma variedade de tarefas, como:\n\n* Entender e gera textos\n* Fazer traduções\n* Responder perguntas\n* Classificar texto\n* Gerar texto baseado em um prompt\n\nLLaMA é conhecido por sua habilidade em capturar a estrutura e a linguagem natural das frases e sentenças.\n\n**LangChain**\n\nLangChain é um modelo de linguagem mais recente, desenvolvido com o objetivo de melhorar a habilidade de conversas e diálogos naturais. Ele é treinado em grandes quantidades de dados de conversas reais e é capaz de:\n\n* Conduzir conversas naturais e fluídas\n* Compreender e responder à linguagem natural\n* Fazer perguntas e respostas\n* Gerar texto baseado em um prompt\n\nLangChain é projetado para ser mais humano-like e fácil para interagir com, especialmente em contextos de conversas prolongadas.\n\n**Diferenças chave**\n\nAs principais diferenças entre LLaMA e LangChain são:\n\n* Tamanho do modelo: LangChain é um modelo mais amplo e complexo que LLaMA, com muitos mais parâmetros e uma arquitetura mais flexível.\n* Treinamento: LLaMA é treinado em uma variedade de tarefas, enquanto LangChain é treinado principalmente para conversas e diálogos naturais.\n* Objetivo: LLaMA é projetado para ser mais generalista e flexível, enquanto LangChain é projetado para ser mais especializado em conversas e diálogos.\n\nEm resumo, LLaMA é um modelo mais amplo e flexível que pode ser usado para uma variedade de tarefas, enquanto LangChain é mais especializado em conversas e diálogos naturais.', role='assistant', executed_tools=None, function_call=None, reasoning=None, tool_calls=None))], created=1746218944, model='llama3-8b-8192', object='chat.completion', system_fingerprint='fp_dadc9d6142', usage=CompletionUsage(completion_tokens=523, prompt_tokens=30, total_tokens=553, completion_time=0.435833333, prompt_time=0.00407261, queue_time=0.018215079, total_time=0.439905943), usage_breakdown=UsageBreakdown(models=None), x_groq={'id': 'req_01jt9c521bevb8n6bs0rze0xjg'})

# %%
print(response.choices[0].message.content)
# Out:
# LLaMA (Large Language Model Application) e LangChain são dois projetos de linguagem natural (Linguagem Natural - LNH) desenvolvidos pela Meta AI, uma empresa líder em tecnologia de linguagem natural e inteligência artificial. Embora ambos sejam modelos de linguagem, existem algumas diferenças importantes entre eles.
#
# **LLaMA**
#
# LLaMA é um modelo de linguagem baseado em transformadores, similar ao BERT e ao RoBERTa. Ele é treinado em uma vasta quantidade de dados de linguagem natural e é capaz de realizar uma variedade de tarefas, como:
#
# * Entender e gera textos
# * Fazer traduções
# * Responder perguntas
# * Classificar texto
# * Gerar texto baseado em um prompt
#
# LLaMA é conhecido por sua habilidade em capturar a estrutura e a linguagem natural das frases e sentenças.
#
# **LangChain**
#
# LangChain é um modelo de linguagem mais recente, desenvolvido com o objetivo de melhorar a habilidade de conversas e diálogos naturais. Ele é treinado em grandes quantidades de dados de conversas reais e é capaz de:
#
# * Conduzir conversas naturais e fluídas
# * Compreender e responder à linguagem natural
# * Fazer perguntas e respostas
# * Gerar texto baseado em um prompt
#
# LangChain é projetado para ser mais humano-like e fácil para interagir com, especialmente em contextos de conversas prolongadas.
#
# **Diferenças chave**
#
# As principais diferenças entre LLaMA e LangChain são:
#
# * Tamanho do modelo: LangChain é um modelo mais amplo e complexo que LLaMA, com muitos mais parâmetros e uma arquitetura mais flexível.
# * Treinamento: LLaMA é treinado em uma variedade de tarefas, enquanto LangChain é treinado principalmente para conversas e diálogos naturais.
# * Objetivo: LLaMA é projetado para ser mais generalista e flexível, enquanto LangChain é projetado para ser mais especializado em conversas e diálogos.
#
# Em resumo, LLaMA é um modelo mais amplo e flexível que pode ser usado para uma variedade de tarefas, enquanto LangChain é mais especializado em conversas e diálogos naturais.

# %% [markdown]
# ### Stream

# %%
mensagens = [
    {
        "role": "user",
        "content": "Explique a diferença entre llm e langchain. Responda em português" 
    }
]

stream = client.chat.completions.create(
    messages=mensagens,
    model="llama3-8b-8192",
    stream=True
)

for chunck in stream:
    print(chunck.choices[0].delta.content, end="", flush=True)
# Out:
# Os termos LLaMA e LangChain são frequentemente mencionados no contexto de modelos de linguagem baseados em máquina, mas muitas pessoas podem não entender bem a diferença entre eles.
#
# LLaMA e LangChain são ambos modelos de linguagem treinados por meio de técnicas de aprendizado de máquina e baseados em modelos de linguagem seqüencial, como os modelos de linguagem geradores de texto. No entanto, a principal diferença entre eles é a abordagem utilizada no treinamento e no funcionamento dos modelos.
#
#  LLama é um modelo de linguagem desenvolvido pela Meta AI e é baseado no modelo de linguagem Gerador de Texto Original (T5). LLaMA é um modelo de linguagem condicional, que significa que pode gerar texto condição a um texto de entrada específico. Ele foi treinado com uma combinação de dados de texto web e dados de conversas, o que o permite gerar texto natural e responder a perguntas e sentenças.
#
# LangChain, por outro lado, é um modelo de linguagem mais recente desenvolvido pela empresa de tecnologia de linguagem, LangChain. Ele é também um modelo de linguagem condicional, mas com um foco maior em responder perguntas e fornecer informações precisas. LangChain foi treinado com uma combinação de dados de perguntas e respostas, além de dados web e conversas.
#
# Outra diferença importante entre LLaMA e LangChain é a escala dos modelos. LLaMA tem um tamanho de modelos mais pequeno, cerca de 1,5 bilhão de parâmetros, enquanto LangChain tem um tamanho de modelo muito maior, cerca de 100 bilhões de parâmetros. Isso significa que LangChain pode lidar com problemas mais complexos e fornecer respostas mais precisas.
#
# Em resumo, a principal diferença entre LLaMA e LangChain é a abordagem utilizada no treinamento e no funcionamento dos modelos, bem como a escala dos modelos. LLaMA é um modelo de linguagem condicional mais pequeno, desenvolvido pela Meta AI, enquanto LangChain é um modelo de linguagem condicional mais grande e avançado, desenvolvido pela LangChain.None

# %% [markdown]
# ### Transcrição de Áudio

# %%
import textwrap

def format_text(response):
    text = response.text
    text_formatted = textwrap.fill(text, width=100)
    print(text_formatted)

# %%
from groq import Groq

client = Groq()

arquivo = "../assets/curso.mp3"

with open(arquivo, "rb") as audio:
    transcricao = client.audio.transcriptions.create(
        file=(arquivo, audio.read()),
        model="whisper-large-v3",
        response_format="json",
        language="pt",
        prompt="Este é um curso de Hugging Face que usa aplicação com Gradio"
    )
    
    format_text(transcricao)
# Out:
#  Seja muito bem-vindo e bem-vinda ao curso Desbravando a IA com Python Explorando modelos de Hugging
# Face Neste curso eu quero te mostrar uma das maiores plataformas de inteligência artificial que
# possui diversos modelos prontos que é a plataforma do Hugging Face E o meu objetivo neste curso é
# explorar dois tipos de modelos Modelos relacionados a processamento de linguagem natural onde
# estaremos trabalhando com análise de sentimentos, vamos trabalhar também com informações de
# perguntas e respostas, vamos trabalhar também com modelos que nos ajudem a resumir textos e assim
# por diante. Por outro lado, nós teremos também modelos relacionados à visão computacional. Estaremos
# trabalhando com aplicações para segmentar imagens, classificar imagens, detectar objetos e muito
# mais. Space além disso em algumas sessões você vai ter a oportunidade de construir o teu modelo é
# uma interface web para o teu modelo utilizando a biblioteca Gradio e também vamos aprender a colocar
# a aplicação que construirmos em produção utilizando o Hugging Face no Space espero que você possa
# estar empolgado para esse curso pois estou muito empolgado para disseminar esse conhecimento

# %% [markdown]
# ### Vision

# %%
import textwrap

def format_text(response):
    text = response.content
    text_formatted = textwrap.fill(text, width=100)
    print(text_formatted)

# %%
completion = client.chat.completions.create(
    model="meta-llama/llama-4-scout-17b-16e-instruct",
    messages=[{
        "role": "user",
        "content":[
            {"type": "text", "text":"O que há nessa imagem?"},
            {"type":"image_url", "image_url": {
                "url": "https://www.civitatis.com/blog/wp-content/uploads/2023/12/shutterstock_318248558-scaled.jpg"
            }}
        ]
    }],
    temperature=1,
    max_completion_tokens=1024,
    top_p=1,
    stream=False,
    stop=None
)

# %%
format_text(completion.choices[0].message)
# Out:
# Nessa imagem há uma praia com muitas pessoas, alguns guarda-sóis e guarda-chuvas espalhados pela
# areia, com algumas palmeiras, prédios e montanhas ao fundo.
