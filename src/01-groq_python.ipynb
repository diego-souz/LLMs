# %%
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv())
# Out:
# True

# %%
from groq import Groq
client = Groq()

# %%
mensagens = [
    {
        "role": "user",
        "content": "Explique a diferença entre llm e langchain. Responda em português" 
    }
]

response = client.chat.completions.create(
    messages=mensagens,
    model="llama3-8b-8192"
)

response
# Out:
# ChatCompletion(id='chatcmpl-ae8e38fa-be12-4db4-9e4c-688e6f7c8ace', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='LLaMA (Large Language Model application) e LangChain são ambos modelos de linguagem pre-treinados com base em técnicas de linguagem natural e aprendizado de máquina. No entanto, eles têm algumas diferenças clave:\n\n**LLaMA (Large Language Model application)**\n\n* É um modelo desenvolvido pelo Research Scientists da Meta AI (antiga Facebook AI) e pela academia.\n* É baseado no modelo de linguagem generativa LLaMA-Base, que é treinado em um grande conjunto de dados de textos da internet.\n* Tem capacidade para entender e gerar textos lengthy e articulados, com uma grande flexibilidade na escolha das frases e das sentenças.\n* É conhecido por suas habilidades de conversação fluída e sua capacidade de responder a perguntas complexas.\n\n**LangChain**\n\n* É um modelo baseado em Lang8, um projeto de tradução chamado "Lang-8" que foi desenvolvido por uma comunidade de voluntários.\n* É treinado em um conjunto de dados de textos traduzidos e não traduzidos.\n* Possui uma abordagem mais focalizada na tradução, com habilidades para traduzir textos de uma língua para outra.\n* Tem uma capacidade menor para gerar textos originários, embora possa gerar textos decentes com a condição de uma linguagem mais simples.\n\nEm resumo, LLaMA é mais focado na geração de textos e conversas fluentes, enquanto LangChain é mais orientado para a tradução e a geração de textos simplificados.', role='assistant', function_call=None, tool_calls=None))], created=1737604065, model='llama3-8b-8192', object='chat.completion', system_fingerprint='fp_6a6771ae9c', usage=CompletionUsage(completion_tokens=351, prompt_tokens=30, total_tokens=381, completion_time=0.2925, prompt_time=0.011433142, queue_time=0.036833558, total_time=0.303933142), x_groq={'id': 'req_01jj8mbt0bfst8ejc9h20v831p'})

# %%
print(response.choices[0].message.content)
# Out:
# LLaMA (Large Language Model application) e LangChain são ambos modelos de linguagem pre-treinados com base em técnicas de linguagem natural e aprendizado de máquina. No entanto, eles têm algumas diferenças clave:
#
# **LLaMA (Large Language Model application)**
#
# * É um modelo desenvolvido pelo Research Scientists da Meta AI (antiga Facebook AI) e pela academia.
# * É baseado no modelo de linguagem generativa LLaMA-Base, que é treinado em um grande conjunto de dados de textos da internet.
# * Tem capacidade para entender e gerar textos lengthy e articulados, com uma grande flexibilidade na escolha das frases e das sentenças.
# * É conhecido por suas habilidades de conversação fluída e sua capacidade de responder a perguntas complexas.
#
# **LangChain**
#
# * É um modelo baseado em Lang8, um projeto de tradução chamado "Lang-8" que foi desenvolvido por uma comunidade de voluntários.
# * É treinado em um conjunto de dados de textos traduzidos e não traduzidos.
# * Possui uma abordagem mais focalizada na tradução, com habilidades para traduzir textos de uma língua para outra.
# * Tem uma capacidade menor para gerar textos originários, embora possa gerar textos decentes com a condição de uma linguagem mais simples.
#
# Em resumo, LLaMA é mais focado na geração de textos e conversas fluentes, enquanto LangChain é mais orientado para a tradução e a geração de textos simplificados.

# %% [markdown]
# ### Stream

# %%
mensagens = [
    {
        "role": "user",
        "content": "Explique a diferença entre llm e langchain. Responda em português" 
    }
]

stream = client.chat.completions.create(
    messages=mensagens,
    model="llama3-8b-8192",
    stream=True
)

for chunck in stream:
    print(chunck.choices[0].delta.content, end="", flush=True)
# Out:
# LLaMA (Large Language Model Application) e LangChain são dois subprojetos do ecossistema de linguagem natural (NLP) desenvolvidos pela Meta AI, empresa criadora do Facebook.
#
# A principal diferença entre LLaMA e LangChain é o objetivo e a abordagem para lidar com linguagem natural.
#
# **LLaMA**
#
# LLaMA (Large Language Model Application) é um projeto que se concentra em criar modelos de linguagem grandes e robustos para realizar tarefas de processamento de linguagem natural, como:
#
# * Gerar texto: LLaMA pode gerar texto original e coherente para uma variedade de tarefas, como resumos, histórias, textos de marketing, etc.
# * Classificação de texto: LLaMA pode classificar texto com base em categorias, sentimentos, emoções, etc.
# * Tradução: LLaMA pode traduzir texto de um idioma para outro.
#
# LLaMA é baseado em modelos de linguagem pré-treinados com grandes dataset de linguagem, como o dataset de texto gigante de 45 bilhões de palavras. Isso permite que o modelo aprenda a reconhecer padrões e relações linguísticas complexas.
#
# **LangChain**
#
# LangChain (Large-scale Language Chain) é um projeto que se concentra em criar uma cadeia de linguagem auto-regressiva, que é um tipo de modelo de linguagem que processa linguagem natural de forma sequencial, usando uma forma de linguagem chamada "cadeia de marca" (token).
#
# LangChain é projetado para realizar tarefas de processamento de linguagem natural que envolvem sequências de linguagem, como:
#
# * Geração de texto condicional: LangChain pode gerar texto condicionalmente com base em uma sequência de entrada.
# * Previsão de sequência de linguagem: LangChain pode prever a próxima palavra ou sequência de linguagem de um texto.
#
# LangChain é baseado em modelos de linguagem pré-treinados e aplica técnicas de aprendizado supervisionado e não supervisionado para melhorar as suas habilidades.
#
# **Resumo**
#
# Em resumo, LLaMA é mais um modelo de linguagem geral, projetado para realizar uma variedade de tarefas de processamento de linguagem natural, enquanto LangChain é mais um modelo de linguagem sequencial, projetado para realizar tarefas que envolvem sequências de linguagem.
#
# Ambos os modelos são importantes para o avanço da inteligência artificial e do processo de linguagem natural, e podem ser usados conjuntamente para melhorar as habilidades de processamento de linguagem natural em aplicações diferentes.None

# %% [markdown]
# ### Transcrição de Áudio

# %%
import textwrap

def format_text(response):
    text = response.text
    text_formatted = textwrap.fill(text, width=100)
    print(text_formatted)

# %%
from groq import Groq

client = Groq()

arquivo = "files/curso.mp3"

with open(arquivo, "rb") as audio:
    transcricao = client.audio.transcriptions.create(
        file=(arquivo, audio.read()),
        model="whisper-large-v3",
        response_format="json",
        language="pt",
        prompt="Este é um curso de Hugging Face que usa aplicação com Gradio"
    )
    
    format_text(transcricao)
# Out:
#  Seja muito bem-vindo e bem-vinda ao curso Desbravando a IA com Python Explorando modelos de Hugging
# Face Neste curso eu quero te mostrar uma das maiores plataformas de inteligência artificial que
# possui diversos modelos prontos que é a plataforma do Hugging Face E o meu objetivo neste curso é
# explorar dois tipos de modelos Modelos relacionados a processamento de linguagem natural onde
# estaremos trabalhando com análise de sentimentos, vamos trabalhar também com informações de
# perguntas e respostas, vamos trabalhar também com modelos que nos ajudem a resumir textos e assim
# por diante. Por outro lado, nós teremos também modelos relacionados à visão computacional. Estaremos
# trabalhando com aplicações para segmentar imagens, classificar imagens, detectar objetos e muito
# mais. Space além disso em algumas sessões você vai ter a oportunidade de construir o teu modelo é
# uma interface web para o teu modelo utilizando a biblioteca Gradio e também vamos aprender a colocar
# a aplicação que construirmos em produção utilizando o Hugging Face no Space espero que você possa
# estar empolgado para esse curso pois estou muito empolgado para disseminar esse conhecimento

# %% [markdown]
# ### Vision

# %%
import textwrap

def format_text(response):
    text = response.content
    text_formatted = textwrap.fill(text, width=100)
    print(text_formatted)

# %%
completion = client.chat.completions.create(
    model="llama-3.2-11b-vision-preview",
    messages=[{
        "role": "user",
        "content":[
            {"type": "text", "text":"O que há nessa imagem?"},
            {"type":"image_url", "image_url": {
                "url": "https://www.civitatis.com/blog/wp-content/uploads/2023/12/shutterstock_318248558-scaled.jpg"
            }}
        ]
    }],
    temperature=1,
    max_completion_tokens=1024,
    top_p=1,
    stream=False,
    stop=None
)

# %%
format_text(completion.choices[0].message)
# Out:
# A essa imagem que se identifica uma praia. No fundo do relevo (em destaque branco) pode ser
# identificado um monte, além de algumas torres. Essas torres tem uma verticalidade caracteristica à
# construções de metropoles. Além disso, a imagem também tem casinhas junto à praia, bem próximas o
# bastante de não fazer com que a praia fique assoalhada. Essas casinhas devem servir como
# acomodações. Sempre, a imagem indica ao espectador que a praia está próxima de um local habitado.
# Essas acomodações nas proximidades da praia, com características de turísticas, indicam que essa
# praia possui uma atractividade a estas pessoas.  Essas acomodações possuirem uma verticalidade
# semelhante à ocupação humana (ponto de partida deste argumento e sendo as únicas estruturas
# similares às habitações) dada pelo monte destaque em baixo, junto à praia da imagem, devem servir de
# hospedagem nas distancias desde o monte e o mar. Então, a praia da imagem deve ser uma praia que um
# turista ou morador de alguma outras localidades se acomoda para um dia de lazer, o quais incluem
# este tipo de acomodações próximas à praia em um local próximo.  Outra característica observada é a
# enorme quantidade de pessoas não deslocadas da acomodação (sua ausência é evidênte) fazendo
# atividade no mar ou em locais ao redor.   Finalmente, tendo em consideração o relevo, localização,
# ocupação e relação (inserção) do local em relação à foto fotografia que o reproduz, indica-se que
# identifica-se prudentialmente, a praia Ilha de Paquetá, no estado do Rio de Janeiro.
